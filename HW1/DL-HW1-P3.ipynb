# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Part $a$ #

# %%
df = pd.read_csv('Heart_Disease_Dataset.csv')

# a)
print("a)")
# i)
print("i)")
Heart_Disease_Dataset_len = len(df)
print("Heart_Disease_Dataset_len: ", Heart_Disease_Dataset_len)
print("----------------------------------------")

# ii)
print("ii)")
missing_data = df.isnull()
if missing_data.any(axis=1).value_counts().values[0] < Heart_Disease_Dataset_len:
    print("the number of missing data in the dataset is ", is_missing.value_counts().values[1])
else :
    print("there is no missing data in the dataset")
print("----------------------------------------")

# iii)
print("iii)")
balanceness = df['target'].value_counts()
if balanceness[0] > balanceness[1]:
    print("the dataset is balanced")
else :
    print("the dataset is imbalanced")
print("----------------------------------------")

# iv)
print("iv)")

# Plot age and sex distribution for each class
plt.figure(figsize=(20, 10))
for i in range(2):
    plt.subplot(2, 2, i+1)
    plt.hist(df[df['target'] == i]['age'], bins=20)
    plt.title('Age distribution for class {}'.format(i))
    plt.xlabel('Age')
    plt.ylabel('Frequency')
    plt.subplot(2, 2, i+3)
    plt.hist(2 * df[df['target'] == i]['sex'], bins=2, width=0.1)
    plt.title('Sex distribution for class {}'.format(i))
    plt.xlabel('Sex (0:F, 1:M)')
    plt.ylabel('Frequency')
# Out:
# a)
# i)
# Heart_Disease_Dataset_len:  1190
# ----------------------------------------
# ii)
# there is no missing data in the dataset
# ----------------------------------------
# iii)
# the dataset is imbalanced
# ----------------------------------------
# iv)

# %% [markdown]
# # Part $ii$ #

# %%
# b)
print("b)")
# delete the outliers using z-score
columns = ['age', 'resting bp s', 'cholesterol', 'max heart rate', 'oldpeak']

z = np.abs(stats.zscore(df[columns]))
threshold = 3
df = df[(z < threshold).all(axis=1)]
print("the number of outliers deleted: ", Heart_Disease_Dataset_len - len(df))
print("----------------------------------------")
print("final dataset length: ", len(df))
# Out:
# b)
# the number of outliers deleted:  28
# ----------------------------------------
# final dataset length:  1162

# %%
# c)
print("c)")
# nurmalize the dataset
df[columns] = (df[columns] - df[columns].mean()) / df[columns].std()
# Out:
# c)

# %%
# d)
print("d)")
# split the dataset to train and test
X = df.drop(['target'], axis=1)
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
# Out:
# d)

# %%
# i)
print("i)")
# train with linear kernel
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report , precision_score, recall_score, f1_score
from sklearn.model_selection import GridSearchCV

svc = SVC(kernel='linear')
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)
print("Linear Kernel:")
print("accuracy score: ", accuracy_score(y_test, y_pred))
print("Percision: ", precision_score(y_test, y_pred))
print("Recall: ", recall_score(y_test, y_pred))
print("F1: ", f1_score(y_test, y_pred))
print("----------------------------------------")

# ii)
print("ii)")
svc = SVC(kernel='rbf')
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)
print("RBF Kernel:")
print("accuracy score: ", accuracy_score(y_test, y_pred))
print("Percision: ", precision_score(y_test, y_pred))
print("Recall: ", recall_score(y_test, y_pred))
print("F1: ", f1_score(y_test, y_pred))
print("----------------------------------------")

# iii)
print("iii)")
svc = SVC(kernel='poly')
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)
print("Polynomial Kernel:")
print("accuracy score: ", accuracy_score(y_test, y_pred))
print("Percision: ", precision_score(y_test, y_pred))
print("Recall: ", recall_score(y_test, y_pred))
print("F1: ", f1_score(y_test, y_pred))
print("----------------------------------------")
# Out:
# i)
# Linear Kernel:
# accuracy score:  0.8108882521489972
# Percision:  0.8186813186813187
# Recall:  0.8186813186813187
# F1:  0.8186813186813187
# ----------------------------------------
# ii)
# RBF Kernel:
# accuracy score:  0.8538681948424068
# Percision:  0.8540540540540541
# Recall:  0.8681318681318682
# F1:  0.8610354223433242
# ----------------------------------------
# iii)
# Polynomial Kernel:
# accuracy score:  0.830945558739255
# Percision:  0.847457627118644
# Recall:  0.8241758241758241
# F1:  0.8356545961002785
# ----------------------------------------

# %% [markdown]
# I did not need to change gamma for RBF kernel. I used the same gamma as the default value.
